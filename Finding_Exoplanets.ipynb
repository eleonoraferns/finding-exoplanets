# %% [markdown]
# <a href="https://colab.research.google.com/github/eleonoraferns/finding-exoplanets/blob/main/Finding_Exoplanets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This model takes data of the brightness levels of stars as recorded by the Kepler Space Telescope and uses it to predict which stars have planets

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
#import the training dataset
train_df = pd.read_csv("https://s3-student-datasets-bucket.whjr.online/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTrain.csv")
train_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6  FLUX.7  \
# 0      2    93.85    83.81    20.10   -26.98   -39.56  -124.71 -135.18
# 1      2   -38.88   -33.83   -58.54   -40.09   -79.31   -72.81  -86.55
# 2      2   532.64   535.92   513.73   496.92   456.45   466.00  464.50
# 3      2   326.52   347.39   302.35   298.13   317.74   312.70  322.33
# 4      2 -1107.21 -1112.59 -1118.95 -1095.10 -1057.55 -1034.48 -998.34
#
#     FLUX.8  FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0   -96.27  -79.89  ...     -78.07    -102.15    -102.15      25.13
# 1   -85.33  -83.97  ...      -3.28     -32.21     -32.21     -24.89
# 2   486.39  436.56  ...     -71.69      13.31      13.31     -29.89
# 3   311.31  312.42  ...       5.71      -3.73      -3.73      30.05
# 4 -1022.71 -989.57  ...    -594.37    -401.66    -401.66    -357.24
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
#inport testing dataset
test_df=pd.read_csv("https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/kepler-exoplanets-dataset/exoTest.csv")
test_df.head()
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0      2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1      2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2      2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3      2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4      2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
#
#     FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0     6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1  5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2   362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3  -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4   -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
train_df.describe()
# Out:
#              LABEL        FLUX.1        FLUX.2        FLUX.3        FLUX.4  \
# count  5087.000000  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03
# mean      1.007273  1.445054e+02  1.285778e+02  1.471348e+02  1.561512e+02
# std       0.084982  2.150669e+04  2.179717e+04  2.191309e+04  2.223366e+04
# min       1.000000 -2.278563e+05 -3.154408e+05 -2.840018e+05 -2.340069e+05
# 25%       1.000000 -4.234000e+01 -3.952000e+01 -3.850500e+01 -3.505000e+01
# 50%       1.000000 -7.100000e-01 -8.900000e-01 -7.400000e-01 -4.000000e-01
# 75%       1.000000  4.825500e+01  4.428500e+01  4.232500e+01  3.976500e+01
# max       2.000000  1.439240e+06  1.453319e+06  1.468429e+06  1.495750e+06
#
#              FLUX.5        FLUX.6        FLUX.7        FLUX.8        FLUX.9  \
# count  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03  5.087000e+03
# mean   1.561477e+02  1.469646e+02  1.168380e+02  1.144983e+02  1.228639e+02
# ...

# %%
test_df.describe()
# Out:
#             LABEL         FLUX.1         FLUX.2         FLUX.3         FLUX.4  \
# count  570.000000     570.000000     570.000000     570.000000     570.000000
# mean     1.008772     515.411351     738.046404     532.603246     739.618088
# std      0.093329   12592.950138   12622.940170   12545.065255   12591.933126
# min      1.000000  -59421.000000  -14663.430000  -56580.000000  -10817.590000
# 25%      1.000000     -22.230000     -22.912500     -22.985000     -18.662500
# 50%      1.000000       1.195000       0.410000      -1.125000      -0.880000
# 75%      1.000000      98.317500      89.710000      89.827500      73.257500
# max      2.000000  290882.500000  290653.500000  290554.000000  290486.500000
#
#               FLUX.5         FLUX.6         FLUX.7         FLUX.8  \
# count     570.000000     570.000000     570.000000     570.000000
# mean      530.949807     729.591491     517.421404     720.723544
# std     12512.976544   12572.187328   12454.094432   12525.496793
# ...

# %%
#print number of rows and columns
train_df.shape
# Out:
# (5087, 3198)

# %%
test_df.shape
# Out:
# (570, 3198)

# %%
#check for missing values in the train dataset
missing=0
for c in train_df.columns:
  for r in train_df[c].isnull():
    if r:
      train_df.isnull().sum()
print(f'The number of missing values is {missing}')
# Out:
# The number of missing values is 0

# %%
#check for missing values in the test dataset
missing=0
for c in test_df.columns:
  for r in test_df[c].isnull():
    if r:
      test_df.isnull().sum()
print(f'The number of missing values is {missing}')
# Out:
# The number of missing values is 0

# %%
#get the number of stars having planets
train_df['LABEL'].value_counts()
# Out:
# 1    5050
# 2      37
# Name: LABEL, dtype: int64

# %%
test_df['LABEL'].value_counts()
# Out:
# 1    565
# 2      5
# Name: LABEL, dtype: int64

# %% [markdown]
# Stars that have a planet are labelled as 2 and the one's that do not are labelled 1

# %% [markdown]
# As a periodic dip can be seen in the flux values of star 0, there could be at least one planet.

# %% [markdown]
# For more accuracy, the data must be normalised

# %%
#create a function to normalise data
def mean_mormalise(series):
  norm_ser = (series - series.mean())/(series.max()-series.min())
  return norm_ser

# %%
#apply the mean_normalise function on the data frame
norm_train_df = train_df.iloc[:, 1:].apply(mean_mormalise, axis=1)
norm_train_df.insert(loc=0, column= 'LABEL', value= train_df['LABEL'])
norm_train_df.head()
# Out:
#    LABEL    FLUX.1    FLUX.2    FLUX.3    FLUX.4    FLUX.5    FLUX.6  \
# 0      2  0.053834  0.047391  0.006510 -0.023699 -0.031772 -0.086410
# 1      2 -0.050411 -0.042317 -0.081922 -0.052351 -0.115212 -0.104794
# 2      2  0.243983  0.245509  0.235186  0.227365  0.208538  0.212981
# 3      2  0.518501  0.551177  0.480659  0.474051  0.504754  0.496863
# 4      2 -0.399904 -0.401872 -0.404199 -0.395473 -0.381734 -0.373293
#
#      FLUX.7    FLUX.8    FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  \
# 0 -0.093128 -0.068161 -0.057650  ...  -0.056482  -0.071934  -0.071934
# 1 -0.126816 -0.124861 -0.122681  ...   0.006648  -0.039721  -0.039721
# 2  0.212283  0.222467  0.199285  ...  -0.037161   0.002382   0.002382
# 3  0.511941  0.494687  0.496425  ...   0.016215   0.001435   0.001435
# 4 -0.360070 -0.368986 -0.356861  ...  -0.212262  -0.141752  -0.141752
#
#    FLUX.3191  FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
norm_test_df = test_df.iloc[:, 1:].apply(mean_mormalise, axis=1)
norm_test_df.insert(loc=0, column= 'LABEL', value= test_df['LABEL'])
norm_test_df.head()
# Out:
#    LABEL    FLUX.1    FLUX.2    FLUX.3    FLUX.4    FLUX.5    FLUX.6  \
# 0      2  0.273347  0.228221  0.196676  0.110003  0.104130  0.088690
# 1      2  0.394038  0.391480  0.392680  0.390974  0.388955  0.386673
# 2      2  0.648150  0.627582  0.591444  0.519002  0.466046  0.385214
# 3      2 -0.232813 -0.233212 -0.238944 -0.235869 -0.208281 -0.220224
# 4      2 -0.006994  0.003426  0.006382  0.007610  0.003316 -0.000167
#
#      FLUX.7    FLUX.8    FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  \
# 0  0.040926  0.014337  0.013534  ...   0.031635   0.042578   0.031451
# 1  0.386340  0.382364  0.381035  ...  -0.047311  -0.075404  -0.092643
# 2  0.340496  0.281192  0.162553  ...   0.018179  -0.034769  -0.032201
# 3 -0.222214 -0.208586 -0.197319  ...   0.056186   0.047254   0.047254
# 4  0.010016 -0.009471  0.008195  ...  -0.006247  -0.016795  -0.001531
#
#    FLUX.3191  FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# ...

# %%
#create pandas series for different stars
star_0= norm_train_df.iloc[0,:]
star_0.head()
# Out:
# LABEL     2.000000
# FLUX.1    0.053834
# FLUX.2    0.047391
# FLUX.3    0.006510
# FLUX.4   -0.023699
# Name: 0, dtype: float64

# %%
star_1 = norm_train_df.iloc[1, :]
star_1.head()
# Out:
# LABEL     2.000000
# FLUX.1   -0.050411
# FLUX.2   -0.042317
# FLUX.3   -0.081922
# FLUX.4   -0.052351
# Name: 1, dtype: float64

# %%
#last star
star_m1 = norm_train_df.iloc[-1, :]
star_m1.head()
# Out:
# LABEL     1.000000
# FLUX.1    0.219815
# FLUX.2    0.208122
# FLUX.3    0.199000
# FLUX.4    0.195206
# Name: 5086, dtype: float64

# %% [markdown]
# We'll plot the flux values to better visialise the star. If there is a periodic dip in the intensity of the light from the star, it would imply that there could possibly be at least one planet revolving around it.

# %%
#plot charts for the stars for 1000 flux values
plt.figure(figsize=(12,3))
x_0=np.arange(1,1001)
y_0=star_0[1:1001]
plt.plot(x_0, y_0)

# %%
#plot the flux values for star 1
plt.figure(figsize=(12,3))
x_1=np.arange(1,1001)
y_1=star_1[1:1001]
plt.plot(x_1, y_1)

# %% [markdown]
# As seen from the line plot, the intensity of star_1 drops consistently and at a higher rate. this could be indicative of the possibility of a fast revolving planet. The planet could also be quite clos to the star.
#
# Lets visualize the plots for the last star

# %%
#plot the flux values for star m1
plt.figure(figsize=(12,3))
x_m1=np.arange(1,1001)
y_m1=star_1[1:1001]
plt.plot(x_m1, y_m1)

# %%
#apply fft on star 0
import numpy as np
fft_star_0 = np.abs(np.fft.fft(star_0))
fft_star_0
# Out:
# array([ 2.        ,  4.25221732, 33.73635408, ..., 35.87366591,
#        33.73635408,  4.25221732])

# %%
#get the frequencies of star_0
freq_star_0 = np.fft.fftfreq(len(star_0))
freq_star_0
# Out:
# array([ 0.        ,  0.0003127 ,  0.00062539, ..., -0.00093809,
#        -0.00062539, -0.0003127 ])

# %%
#create a plot between the transformed and freq values
plt.figure(figsize=(12,3))
plt.plot(freq_star_0[:100],fft_star_0[:100])

# %%
#create a funct to apply fft on the entire train df
def fast_ft(star):
  fft_star=np.abs(np.fft.fft(star, n=len(star)))
  return fft_star

# %%
#apply fast_fft on the transpose of norm_train_df
x_fft_train = norm_train_df.iloc[:,1:].T.apply(fast_ft, axis=0)
x_fft_train= x_fft_train.T
x_fft_train.head()
# Out:
#          FLUX.1      FLUX.2     FLUX.3      FLUX.4      FLUX.5      FLUX.6  \
# 0  6.004706e-15    2.273248  35.722883   33.978236  128.816503   18.835061
# 1  4.094300e-15   30.299298  36.918808   38.376852   22.149931   33.282191
# 2  3.742374e-15   66.809870  19.498262  170.268810   48.413391   88.178733
# 3  8.024386e-15   19.369720  52.151962  108.097894  100.659024  269.416639
# 4  4.881195e-15  113.576655  51.382781  146.597215  148.627668  103.842855
#
#        FLUX.7     FLUX.8     FLUX.9    FLUX.10  ...  FLUX.3188  FLUX.3189  \
# 0   16.101795  10.722037  18.488302  16.400976  ...   1.920231  16.400976
# 1   27.734204  11.862346  14.001221  14.221386  ...  11.833992  14.221386
# 2   57.407061  38.684283  10.503268  46.482585  ...  22.681374  46.482585
# 3   77.435861  71.256558  54.895479  33.335462  ...  26.711804  33.335462
# 4  116.738548  28.957862  36.451207  69.375686  ...   4.923027  69.375686
#
# ...

# %%
#apply fast_fft on the transpose of norm_test_df
x_fft_test = norm_test_df.iloc[:,1:].T.apply(fast_ft, axis=0)
x_fft_test= x_fft_test.T
x_fft_test.head()
# Out:
#          FLUX.1      FLUX.2     FLUX.3     FLUX.4     FLUX.5     FLUX.6  \
# 0  8.950904e-16   23.184733  40.545472  17.994173  13.772498  16.594294
# 1  8.965352e-15  135.637702  42.680618  28.017660  17.672923  16.099550
# 2  1.369225e-14  101.624620  26.553454  11.634754  11.720122  46.153088
# 3  2.373386e-15   37.305651  20.537365   5.108229  16.309293  20.286675
# 4  6.684428e-15    7.138386  11.941614  12.808132  27.841397  39.681676
#
#       FLUX.7     FLUX.8     FLUX.9    FLUX.10  ...  FLUX.3188  FLUX.3189  \
# 0  17.532422   8.094149   8.045917   9.549431  ...   7.981027   9.549431
# 1  62.999485  27.005547  26.735149  29.708628  ...   9.883983  29.708628
# 2  23.677302  22.208643  14.393021   3.278532  ...   7.742408   3.278532
# 3  18.969927   6.010526   8.763040   6.370417  ...  16.668561   6.370417
# 4  17.985758  30.233859  14.800046   8.501530  ...   5.167375   8.501530
#
#    FLUX.3190  FLUX.3191  FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  \
# ...

# %%
#get the feature variables
y_train = norm_train_df.iloc[:,0]
y_train
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 5082    1
# 5083    1
# 5084    1
# 5085    1
# 5086    1
# Name: LABEL, Length: 5087, dtype: int64

# %%
y_test = norm_test_df.iloc[:,0]
y_test
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 565    1
# 566    1
# 567    1
# 568    1
# 569    1
# Name: LABEL, Length: 570, dtype: int64

# %%
#use the random forest classifier to make predictions
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(max_depth=2, random_state=42)
rf_clf.fit(x_fft_train, y_train)
rf_clf.score(x_fft_train, y_train)
# Out:
# 0.9927265578926676

# %%
y_pred = rf_clf.predict(x_fft_test)
y_pred=pd.Series(y_pred)
y_pred.value_counts()
# Out:
# 1    570
# dtype: int64

# %%
#accuracy score
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9912280701754386

# %% [markdown]
# Although the accuracy is high, none of the stars with a star were classified correctly.

# %%
#logistic regression  model
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state=0)
log_reg.fit(x_fft_train, y_train)
log_reg.score(x_fft_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 1.0

# %%
y_pred_lr = log_reg.predict(x_fft_test)
y_pred_lr=pd.Series(y_pred_lr)
y_pred_lr.value_counts()
# Out:
# 1    564
# 2      6
# dtype: int64

# %%
print(f'Accuracy: {accuracy_score(y_test, y_pred_lr)*100} %')
# Out:
# Accuracy: 99.12280701754386 %
